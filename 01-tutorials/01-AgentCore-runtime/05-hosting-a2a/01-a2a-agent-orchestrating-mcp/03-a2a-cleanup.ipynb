# %% [markdown]
# ## CleanUp

# %%
import os
from dotenv import load_dotenv
load_dotenv(override=True)
user_name = os.getenv("USER_NAME")
if not user_name:
    raise ValueError("USER_NAME environment variable is not set. Please set it in the .env file.")

# %%
# %store -r

# %%
from helpers.utils import (
    delete_agentcore_runtime_execution_role,
    delete_ssm_parameter,
    cleanup_cognito_resources,
    get_cognito_secret,
    delete_cognito_secret,
    runtime_resource_cleanup,
    delete_observability_resources,
    local_file_cleanup,
    ecr_repo_cleanup,
    short_memory_cleanup,
    AWS_DOCS_ROLE_NAME,
    ORCHESTRATOR_ROLE_NAME,
    AWS_BLOG_ROLE_NAME,
    SSM_DOCS_AGENT_ARN,
    SSM_BLOGS_AGENT_ARN,
)

print("✅ Dependencies imported successfully")
# Out:
# ✅ Dependencies imported successfully

# %%
from pathlib import Path
from bedrock_agentcore_starter_toolkit.operations.runtime.destroy import destroy_bedrock_agentcore

print("🚀 Starting Runtime cleanup...")
destroy_bedrock_agentcore(
     config_path=Path(".bedrock_agentcore.yaml"),
     agent_name=MCP_AGENT_NAME,
     delete_ecr_repo=True
)
# Out:
# Starting destroy operation for agent: aws_docs_assistant_eric_fu (dry_run=False, delete_ecr_repo=True)
# 🚀 Starting Runtime cleanup...
# DEFAULT endpoint will be automatically deleted with agent
# Deleted AgentCore agent: arn:aws:bedrock-agentcore:us-west-2:372080370602:runtime/aws_docs_assistant_eric_fu-X7QG3rFSOq
# Checking ECR repository: bedrock-agentcore-aws_docs_assistant_eric_fu in region: us-west-2
# Deleted 1 ECR images from bedrock-agentcore-aws_docs_assistant_eric_fu
# Deleted ECR repository: bedrock-agentcore-aws_docs_assistant_eric_fu
# Deleted CodeBuild project: bedrock-agentcore-aws_docs_assistant_eric_fu-builder
# ✅ MemoryManager initialized for region: us-west-2
# Deleted memory: aws_docs_assistant_eric_fu_mem-0NjSKHC9KF
# Deleted memory: aws_docs_assistant_eric_fu_mem-0NjSKHC9KF
# Deleted memory (was created by toolkit): aws_docs_assistant_eric_fu_mem-0NjSKHC9KF
# Deleted inline policy CodeBuildExecutionPolicy from role AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-06c37326ba
# Deleted CodeBuild IAM role: AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-06c37326ba
# Deleted IAM role: AWSDocsAssistantBedrockAgentCoreRole-us-west-2
# Removed agent configuration: aws_docs_assistant_eric_fu
# Updated configuration file
# Destroy operation completed. Resources removed: 8, Warnings: 0, Errors: 0
# DestroyResult(agent_name='aws_docs_assistant_eric_fu', resources_removed=['AgentCore agent: arn:aws:bedrock-agentcore:us-west-2:372080370602:runtime/aws_docs_assistant_eric_fu-X7QG3rFSOq', 'ECR images: 1 images from bedrock-agentcore-aws_docs_assistant_eric_fu', 'ECR repository: bedrock-agentcore-aws_docs_assistant_eric_fu', 'CodeBuild project: bedrock-agentcore-aws_docs_assistant_eric_fu-builder', 'Memory: aws_docs_assistant_eric_fu_mem-0NjSKHC9KF', 'Deleted CodeBuild IAM role: AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-06c37326ba', 'IAM execution role: AWSDocsAssistantBedrockAgentCoreRole-us-west-2', 'Agent configuration: aws_docs_assistant_eric_fu'], warnings=[], errors=[], dry_run=False)

# %%
print("🚀 Starting Runtime cleanup...")
destroy_bedrock_agentcore(
     config_path=Path(".bedrock_agentcore.yaml"),
     agent_name=BLOG_AGENT_NAME,
     delete_ecr_repo=True
)
# Out:
# Starting destroy operation for agent: aws_blog_assistant_eric_fu (dry_run=False, delete_ecr_repo=True)
# DEFAULT endpoint will be automatically deleted with agent
# 🚀 Starting Runtime cleanup...
# Deleted AgentCore agent: arn:aws:bedrock-agentcore:us-west-2:372080370602:runtime/aws_blog_assistant_eric_fu-wm2fy17gHR
# Checking ECR repository: bedrock-agentcore-aws_blog_assistant_eric_fu in region: us-west-2
# Deleted 1 ECR images from bedrock-agentcore-aws_blog_assistant_eric_fu
# Deleted ECR repository: bedrock-agentcore-aws_blog_assistant_eric_fu
# Deleted CodeBuild project: bedrock-agentcore-aws_blog_assistant_eric_fu-builder
# ✅ MemoryManager initialized for region: us-west-2
# Deleted memory: aws_blog_assistant_eric_fu_mem-i6gob9EtlN
# Deleted memory: aws_blog_assistant_eric_fu_mem-i6gob9EtlN
# Deleted memory (was created by toolkit): aws_blog_assistant_eric_fu_mem-i6gob9EtlN
# Deleted inline policy CodeBuildExecutionPolicy from role AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-95420316ba
# Deleted CodeBuild IAM role: AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-95420316ba
# Deleted IAM role: AWSBlogsAssistantBedrockAgentCoreRole-us-west-2
# Removed agent configuration: aws_blog_assistant_eric_fu
# Updated configuration file
# Destroy operation completed. Resources removed: 8, Warnings: 0, Errors: 0
# DestroyResult(agent_name='aws_blog_assistant_eric_fu', resources_removed=['AgentCore agent: arn:aws:bedrock-agentcore:us-west-2:372080370602:runtime/aws_blog_assistant_eric_fu-wm2fy17gHR', 'ECR images: 1 images from bedrock-agentcore-aws_blog_assistant_eric_fu', 'ECR repository: bedrock-agentcore-aws_blog_assistant_eric_fu', 'CodeBuild project: bedrock-agentcore-aws_blog_assistant_eric_fu-builder', 'Memory: aws_blog_assistant_eric_fu_mem-i6gob9EtlN', 'Deleted CodeBuild IAM role: AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-95420316ba', 'IAM execution role: AWSBlogsAssistantBedrockAgentCoreRole-us-west-2', 'Agent configuration: aws_blog_assistant_eric_fu'], warnings=[], errors=[], dry_run=False)

# %%
print("🚀 Starting Runtime cleanup...")
destroy_bedrock_agentcore(
     config_path=Path(".bedrock_agentcore.yaml"),
     agent_name=ORCHESTRATION_NAME,
     delete_ecr_repo=True
)
# Out:
# Starting destroy operation for agent: aws_orchestrator_assistant_eric_fu (dry_run=False, delete_ecr_repo=True)
# DEFAULT endpoint will be automatically deleted with agent
# 🚀 Starting Runtime cleanup...
# Deleted AgentCore agent: arn:aws:bedrock-agentcore:us-west-2:372080370602:runtime/aws_orchestrator_assistant_eric_fu-yUP02XCTYd
# Checking ECR repository: bedrock-agentcore-aws_orchestrator_assistant_eric_fu in region: us-west-2
# Deleted 1 ECR images from bedrock-agentcore-aws_orchestrator_assistant_eric_fu
# Deleted ECR repository: bedrock-agentcore-aws_orchestrator_assistant_eric_fu
# Deleted CodeBuild project: bedrock-agentcore-aws_orchestrator_assistant_eric_fu-builder
# ✅ MemoryManager initialized for region: us-west-2
# Deleted memory: aws_orchestrator_assistant_eric_fu_mem-kaEu1KA0jy
# Deleted memory: aws_orchestrator_assistant_eric_fu_mem-kaEu1KA0jy
# Deleted memory (was created by toolkit): aws_orchestrator_assistant_eric_fu_mem-kaEu1KA0jy
# Deleted inline policy CodeBuildExecutionPolicy from role AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-f6b9cff9fa
# Deleted CodeBuild IAM role: AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-f6b9cff9fa
# Deleted IAM role: AWSOrchestratorAssistantAgentCoreRole-eric_fu-us-west-2
# Removed agent configuration: aws_orchestrator_assistant_eric_fu
# Cleared default agent (no agents remaining)
# Removed configuration file: .bedrock_agentcore.yaml
# Destroy operation completed. Resources removed: 9, Warnings: 0, Errors: 0
# DestroyResult(agent_name='aws_orchestrator_assistant_eric_fu', resources_removed=['AgentCore agent: arn:aws:bedrock-agentcore:us-west-2:372080370602:runtime/aws_orchestrator_assistant_eric_fu-yUP02XCTYd', 'ECR images: 1 images from bedrock-agentcore-aws_orchestrator_assistant_eric_fu', 'ECR repository: bedrock-agentcore-aws_orchestrator_assistant_eric_fu', 'CodeBuild project: bedrock-agentcore-aws_orchestrator_assistant_eric_fu-builder', 'Memory: aws_orchestrator_assistant_eric_fu_mem-kaEu1KA0jy', 'Deleted CodeBuild IAM role: AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-f6b9cff9fa', 'IAM execution role: AWSOrchestratorAssistantAgentCoreRole-eric_fu-us-west-2', 'Agent configuration: aws_orchestrator_assistant_eric_fu', 'Configuration file (no agents remaining)'], warnings=[], errors=[], dry_run=False)

# %%
print("🛡️  Starting Security cleanup...")
import json
try:
    # bedrock_client = boto3.client("bedrock", region_name=REGION)

    # Delete execution role
    print("  🗑️  Deleting Agent 1 - AWS Docs execution role...")
    delete_agentcore_runtime_execution_role(AWS_DOCS_ROLE_NAME)
    print("  ✅ Execution role deleted")

    print("  🗑️  Deleting Agent 2 - AWS Blogs execution role...")
    delete_agentcore_runtime_execution_role(AWS_BLOG_ROLE_NAME)
    print("  ✅ Execution role deleted")

    print("  🗑️  Deleting Orchestration execution role...")
    delete_agentcore_runtime_execution_role(ORCHESTRATOR_ROLE_NAME)
    print("  ✅ Execution role deleted")

    # Clean up Cognito and secrets
    print("  🗑️  Cleaning up Cognito resources...")
    cs = json.loads(get_cognito_secret())
    cleanup_cognito_resources(cs['pool_id'])
    print("  ✅ Cognito resources cleaned up")

    print("  🗑️  Deleting customer support secret...")
    delete_cognito_secret()
    print("  ✅ Customer support secret deleted")

    print("  🗑️  Deleting SSM Parameter...")
    delete_ssm_parameter(SSM_DOCS_AGENT_ARN)
    print("  ✅ SSM parameter deleted")

    print("  🗑️  Deleting SSM Parameter...")
    delete_ssm_parameter(SSM_BLOGS_AGENT_ARN)
    print("  ✅ SSM parameter deleted")

except Exception as e:
    print(f"  ⚠️  Error during security cleanup: {e}")
# Out:
# 🛡️  Starting Security cleanup...
#   🗑️  Deleting Agent 1 - AWS Docs execution role...
# ✅ Deleted policy: AWSDocsAssistantBedrockAgentCorePolicy-us-west-2
#   ✅ Execution role deleted
#   🗑️  Deleting Agent 2 - AWS Blogs execution role...
#   ✅ Execution role deleted
#   🗑️  Deleting Orchestration execution role...
#   ✅ Execution role deleted
#   🗑️  Cleaning up Cognito resources...
# Deleting app client: MCPServerPoolClient
# Deleting user: testuser
# Deleting user pool: us-west-2_nfIB2q9S8
# Successfully cleaned up all Cognito resources
#   ✅ Cognito resources cleaned up
#   🗑️  Deleting customer support secret...
# ✅ Secret Deleted
#   ✅ Customer support secret deleted
#   🗑️  Deleting SSM Parameter...
#   ✅ SSM parameter deleted
#   🗑️  Deleting SSM Parameter...
#   ✅ SSM parameter deleted

# %%
print("📁 Starting Local Files cleanup...")
local_file_cleanup()
# Out:
# 📁 Starting Local Files cleanup...
#   ✅ Deleted Dockerfile
#   ✅ Deleted .dockerignore
#   ✅ Deleted agents/strands_aws_docs.py
#   ✅ Deleted agents/orchestrator.py
#   ✅ Deleted agents/requirements.txt
#   ✅ Deleted agents/strands_aws_blogs_news.py
#
# 📁 Successfully deleted 6 files
# ℹ️  1 files were already missing: .bedrock_agentcore.yaml

# %%
print("📊 Starting Observability cleanup...")
delete_observability_resources(MCP_AGENT_ID)
# Out:
# 📊 Starting Observability cleanup...
#   🗑️  Deleting log stream 'default'...
#   ℹ️  Log stream 'default' doesn't exist
#   🗑️  Deleting log group '/aws/bedrock-agentcore/runtimes/aws_docs_assistant_eric_fu-X7QG3rFSOq-DEFAULT'...
#   ✅ Log group '/aws/bedrock-agentcore/runtimes/aws_docs_assistant_eric_fu-X7QG3rFSOq-DEFAULT' deleted successfully

# %%
print("📊 Starting Observability cleanup...")
delete_observability_resources(BLOG_AGENT_ID)
# Out:
# 📊 Starting Observability cleanup...
#   🗑️  Deleting log stream 'default'...
#   ℹ️  Log stream 'default' doesn't exist
#   🗑️  Deleting log group '/aws/bedrock-agentcore/runtimes/aws_blog_assistant_eric_fu-wm2fy17gHR-DEFAULT'...
#   ✅ Log group '/aws/bedrock-agentcore/runtimes/aws_blog_assistant_eric_fu-wm2fy17gHR-DEFAULT' deleted successfully

# %%
print("📊 Starting Observability cleanup...")
delete_observability_resources(ORCHESTRATION_ID)
# Out:
# 📊 Starting Observability cleanup...
#   🗑️  Deleting log stream 'default'...
#   ℹ️  Log stream 'default' doesn't exist
#   🗑️  Deleting log group '/aws/bedrock-agentcore/runtimes/aws_orchestrator_assistant_eric_fu-yUP02XCTYd-DEFAULT'...
#   ✅ Log group '/aws/bedrock-agentcore/runtimes/aws_orchestrator_assistant_eric_fu-yUP02XCTYd-DEFAULT' deleted successfully
