# %% [markdown]
# # Integrate your own MCP Server into AgentCore Gateway
#
# ## Overview
#
# In large enterprises with thousands of development teams, each running multiple MCP servers with several tools, managing and discovering tools becomes a critical challenge:
#
# * **Tool Discovery and Sharing**: Teams struggle to discover and consume tools across the organization. Should each team maintain separate gateways? How do you share gateway URLs and manage central registries without creating operational overhead?
# * **Gateway Management**: Maintaining separate gateways for each MCP server quickly becomes unmanageable at scale.
# * **Authentication Complexity**: Managing authentication and authorization across multiple MCP servers becomes increasingly complex, especially with sensitive enterprise data.
# * **Maintenance Overhead**: Keeping up with MCP specification updates requires continuous rework and testing across all implementations.
#
# AgentCore Gateway now supports onboarding pre-existing MCP server implementations as targets, in addition to Lambda and OpenAPI tools. This tutorial demonstrates the concept using a simple MCP server in AgentCore Runtime for this implementation.
#
# ![Diagram](images/mcp-server-target.png)
#
# Once the AgentCore Gateway is integrated with the MCP server as a target, we'll search for tools through our integrated MCP server, then we'll use a Strands Agent to demonstrate the list tools and invoke tool functionality. More detail on each of these flows can be found below:
#
# ### Search tool behavior for MCP Targets
#
# The search capability in AgentCore Gateway enables semantic discovery of tools across all target types, including MCP targets. For MCP targets, the search functionality operates on normalized tool definitions that were captured and indexed during synchronization operations, providing efficient semantic search without real-time MCP server communication. When tool definitions are synchronized from an MCP target, Gateway automatically generates embeddings for each tool's name, description, and parameter descriptions. These embeddings are stored alongside the normalized tool definitions, enabling semantic search that understands the intent and context of search queries. Unlike traditional keyword matching, this allows agents to discover relevant tools even when exact terminology doesn't match.
#
# ![Search](images/mcp-server-search-tool.png)
#
# ### ListTools behavior for MCP Targets
#
# The ListTools operation in AgentCore Gateway provides access to tool definitions previously synchronized from MCP targets, following a cache-first approach that prioritizes performance and reliability. Unlike traditional OpenAPI or Lambda targets where tool definitions are statically defined, MCP target tools are discovered and cached through synchronization operations. When a client calls ListTools, the Gateway retrieves tool definitions from its persistent storage rather than making real-time calls to the MCP server. These definitions were previously populated either through implicit synchronization during target creation/update or through explicit SynchronizeGateway API calls. The operation returns a paginated list of normalized tool definitions.
#
# ![List](images/mcp-server-list-tools.png)
#
# ### InvokeTool (tools/call) Behavior for MCP Targets
#
# The InvokeTool operation for MCP targets handles the actual execution of tools discovered through ListTools, managing real-time communication with the target MCP server. Unlike the cache-based ListTools operation, tools/call requires active communication with the MCP server, introducing specific authentication, session management, and error handling requirements. When a tools/call request arrives, Gateway first validates the tool exists in its synchronized definitions. For MCP targets, Gateway performs an initial 'initialize' call to establish a session with the MCP server. If the target is configured with OAuth credentials, Gateway retrieves fresh credentials from AgentCore Identity before making the initialize call. This ensures that even if ListTools returned cached tools with expired credentials, the actual invocation uses valid authentication.
#
# ![Invoke](images/mcp-server-invoke-tool.png)
#
#
# ### Tutorial Details
#
#
# | Information          | Details                                                   |
# |:---------------------|:----------------------------------------------------------|
# | Tutorial type        | Interactive                                               |
# | AgentCore components | AgentCore Gateway, AgentCore Identity                     |
# | Agentic Framework    | Strands Agents                                            |
# | Gateway Target type  | MCP server                                                |
# | Agent                | Strands                                                   |
# | Inbound Auth IdP     | Amazon Cognito, but can use others                        |
# | Outbound Auth        | Amazon Cognito, but can use others                        |
# | LLM model            | Anthropic Claude Sonnet 4                                 |
# | Tutorial components  | Creating AgentCore Gateway and Invoking AgentCore Gateway |
# | Tutorial vertical    | Cross-vertical                                            |
# | Example complexity   | Easy                                                      |
# | SDK used             | boto3                                                     |
#
# ## Tutorial architecture
#
# This tutorial serves as a practical example of the broader enterprise challenge: **How to integrate existing MCP servers into a centralized Gateway architecture.**

# %% [markdown]
# ## Prerequisites
#
# To execute this tutorial you will need:
# * Jupyter notebook (Python kernel)
# * uv
# * AWS credentials
# * Amazon Cognito

# %%
# Install from the requirements file or pyproject.toml file in current directory
# !uv pip install --force-reinstall -U -r requirements.txt --quiet

# %%
import os
from dotenv import load_dotenv
load_dotenv(override=True)
user_name = os.getenv("USER_NAME")
if not user_name:
    raise ValueError("USER_NAME environment variable is not set. Please set it in the .env file.")

# %%
import os
# Set AWS credentials if not using SageMaker notebook
# os.environ['AWS_ACCESS_KEY_ID'] = '' # Set the access key
# os.environ['AWS_SECRET_ACCESS_KEY'] = '' # Set the secret key
os.environ['AWS_DEFAULT_REGION'] = os.environ.get('AWS_REGION', 'us-east-1')

# %%
# Import utils
import os
import sys

# Get the directory of the current script
if '__file__' in globals():
    current_dir = os.path.dirname(os.path.abspath(__file__))
else:
    current_dir = os.getcwd()  # Fallback if __file__ is not defined (e.g., Jupyter)

# Navigate to the directory containing utils.py (one level up)
utils_dir = os.path.abspath(os.path.join(current_dir, '..'))

# Add to sys.path
sys.path.insert(0, utils_dir)

# Now you can import utils
import utils

# Setup logging
import logging

# Configure logging for notebook environment
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s | %(levelname)s | %(name)s | %(message)s",
    handlers=[logging.StreamHandler()]
)

# Set specific logger levels
logging.getLogger("strands").setLevel(logging.INFO)

# %% [markdown]
# ## Create an IAM role for the Gateway to assume

# %%
agentcore_gateway_iam_role = utils.create_agentcore_gateway_role("sample-mcpgateway")
print("Agentcore gateway role ARN: ", agentcore_gateway_iam_role['Role']['Arn'])
# Out:
# 2026-04-09 07:56:18,381 | INFO | botocore.credentials | Found credentials in environment variables.
# attaching role policy agentcore-sample-mcpgateway-role
# Agentcore gateway role ARN:  arn:aws:iam::372080370602:role/agentcore-sample-mcpgateway-role

# %% [markdown]
# ## Create Amazon Cognito Pool for Inbound authorization to Gateway

# %%
# Creating Cognito User Pool
import os
import boto3

REGION = os.environ['AWS_DEFAULT_REGION']
USER_POOL_NAME = "sample-agentcore-gateway-pool-" + user_name
RESOURCE_SERVER_ID = "sample-agentcore-gateway-id"
RESOURCE_SERVER_NAME = "sample-agentcore-gateway-name"
CLIENT_NAME = "sample-agentcore-gateway-client"
SCOPES = [
    {"ScopeName": "invoke",  # Just 'invoke', will be formatted as resource_server_id/invoke
    "ScopeDescription": "Scope for invoking the agentcore gateway"},
]

scope_names = [f"{RESOURCE_SERVER_ID}/{scope['ScopeName']}" for scope in SCOPES]
scopeString = " ".join(scope_names)


cognito = boto3.client("cognito-idp", region_name=REGION)

print("Creating or retrieving Cognito resources...")
gw_user_pool_id = utils.get_or_create_user_pool(cognito, USER_POOL_NAME)
print(f"User Pool ID: {gw_user_pool_id}")

utils.get_or_create_resource_server(cognito, gw_user_pool_id, RESOURCE_SERVER_ID, RESOURCE_SERVER_NAME, SCOPES)
print("Resource server ensured.")

gw_client_id, gw_client_secret = utils.get_or_create_m2m_client(cognito, gw_user_pool_id, CLIENT_NAME, RESOURCE_SERVER_ID, scope_names)

print(f"Client ID: {gw_client_id}")

# Get discovery URL
gw_cognito_discovery_url = f'https://cognito-idp.{REGION}.amazonaws.com/{gw_user_pool_id}/.well-known/openid-configuration'
print(gw_cognito_discovery_url)
# Out:
# Creating or retrieving Cognito resources...
# Creating new user pool
# Domain created as well
# User Pool ID: us-west-2_aXNfsDdi6
# creating new resource server
# Resource server ensured.
# creating new m2m client
# Client ID: 13p3t4o8fr1egchooj4pl9v5vr
# https://cognito-idp.us-west-2.amazonaws.com/us-west-2_aXNfsDdi6/.well-known/openid-configuration

# %% [markdown]
# ## Create Amazon Cognito Pool for Inbound authorization to Runtime
# This section highlights the ability for the gateway to have a separate inbound authentication from its target systems. This allows agents to access tools that use multiple identity providers through a single interface.

# %%
# Creating Cognito User Pool
import os
import boto3

REGION = os.environ['AWS_DEFAULT_REGION']
USER_POOL_NAME = "sample-agentcore-runtime-pool-" + user_name
RESOURCE_SERVER_ID = "sample-agentcore-runtime-id"
RESOURCE_SERVER_NAME = "sample-agentcore-runtime-name"
CLIENT_NAME = "sample-agentcore-runtime-client"
SCOPES = [
    {"ScopeName": "invoke",  # Just 'invoke', will be formatted as resource_server_id/invoke
    "ScopeDescription": "Scope for invoking the agentcore gateway"},
]

scope_names = [f"{RESOURCE_SERVER_ID}/{scope['ScopeName']}" for scope in SCOPES]
runtimeScopeString = " ".join(scope_names)


cognito = boto3.client("cognito-idp", region_name=REGION)

print("Creating or retrieving Cognito resources...")
runtime_user_pool_id = utils.get_or_create_user_pool(cognito, USER_POOL_NAME)
print(f"User Pool ID: {runtime_user_pool_id}")

utils.get_or_create_resource_server(cognito, runtime_user_pool_id, RESOURCE_SERVER_ID, RESOURCE_SERVER_NAME, SCOPES)
print("Resource server ensured.")

runtime_client_id, runtime_client_secret = utils.get_or_create_m2m_client(cognito, runtime_user_pool_id, CLIENT_NAME, RESOURCE_SERVER_ID, scope_names)

print(f"Client ID: {runtime_client_id}")

# Get discovery URL
runtime_cognito_discovery_url = f'https://cognito-idp.{REGION}.amazonaws.com/{runtime_user_pool_id}/.well-known/openid-configuration'
print(runtime_cognito_discovery_url)
# Out:
# Creating or retrieving Cognito resources...
# Creating new user pool
# Domain created as well
# User Pool ID: us-west-2_FqWMIa8yh
# creating new resource server
# Resource server ensured.
# creating new m2m client
# Client ID: 4pk0bckdp6lingfup5ia5j1u5c
# https://cognito-idp.us-west-2.amazonaws.com/us-west-2_FqWMIa8yh/.well-known/openid-configuration

# %% [markdown]
# ## Create the Gateway

# %%
# CreateGateway with Cognito authorizer. Use the Cognito user pool created in the previous step
import boto3
gateway_client = boto3.client('bedrock-agentcore-control', region_name=REGION)
auth_config = {
    "customJWTAuthorizer": {
        "allowedClients": [gw_client_id],  # Client MUST match with the ClientId configured in Cognito. Example: 7rfbikfsm51j2fpaggacgng84g
        "discoveryUrl": gw_cognito_discovery_url
    }
}
create_response = gateway_client.create_gateway(name='ac-gateway-mcp-server-' + user_name.replace("_", "-"),
    roleArn=agentcore_gateway_iam_role['Role']['Arn'], # The IAM Role must have permissions to create/list/get/delete Gateway
    protocolType='MCP',
    protocolConfiguration={
        'mcp': {
            'supportedVersions': ['2025-03-26'],
            'searchType': 'SEMANTIC'
        }
    },
    authorizerType='CUSTOM_JWT',
    authorizerConfiguration=auth_config,
    description='AgentCore Gateway with MCP Server target'
)
print(create_response)
# Retrieve the GatewayID used for GatewayTarget creation
gatewayID = create_response["gatewayId"]
gatewayURL = create_response["gatewayUrl"]
print(gatewayID)
# Out:
# {'ResponseMetadata': {'RequestId': '8a5b8208-291a-4ce9-89a1-9cfa9b27af63', 'HTTPStatusCode': 202, 'HTTPHeaders': {'date': 'Thu, 09 Apr 2026 14:59:50 GMT', 'content-type': 'application/json', 'content-length': '956', 'connection': 'keep-alive', 'x-amzn-requestid': '8a5b8208-291a-4ce9-89a1-9cfa9b27af63', 'x-amz-apigw-id': 'bjrEEHywvHcEJXw=', 'x-amzn-trace-id': 'Root=1-69d7bee6-7d23bd0f4dc6b917241d350f'}, 'RetryAttempts': 0}, 'gatewayArn': 'arn:aws:bedrock-agentcore:us-west-2:372080370602:gateway/ac-gateway-mcp-server-eric-fu-vm1cliffaw', 'gatewayId': 'ac-gateway-mcp-server-eric-fu-vm1cliffaw', 'gatewayUrl': 'https://ac-gateway-mcp-server-eric-fu-vm1cliffaw.gateway.bedrock-agentcore.us-west-2.amazonaws.com/mcp', 'createdAt': datetime.datetime(2026, 4, 9, 14, 59, 50, 519089, tzinfo=tzutc()), 'updatedAt': datetime.datetime(2026, 4, 9, 14, 59, 50, 519097, tzinfo=tzutc()), 'status': 'CREATING', 'name': 'ac-gateway-mcp-server-eric-fu', 'description': 'AgentCore Gateway with MCP Server target', 'roleArn': 'arn:aws:iam::372080370602:role/agentcore-sample-mcpgateway-role', 'protocolType': 'MCP', 'protocolConfiguration': {'mcp': {'supportedVersions': ['2025-03-26'], 'searchType': 'SEMANTIC'}}, 'authorizerType': 'CUSTOM_JWT', 'authorizerConfiguration': {'customJWTAuthorizer': {'discoveryUrl': 'https://cognito-idp.us-west-2.amazonaws.com/us-west-2_aXNfsDdi6/.well-known/openid-configuration', 'allowedClients': ['13p3t4o8fr1egchooj4pl9v5vr']}}, 'workloadIdentityDetails': {}}
# ac-gateway-mcp-server-eric-fu-vm1cliffaw

# %% [markdown]
# ## Create a sample MCP Server and host it in Runtime

# %% [markdown]
# You can replace below with your MCP server that might already exist. This section follows the example in the [Hosting MCP Server on Amazon Bedrock AgentCore Runtime](https://github.com/awslabs/amazon-bedrock-agentcore-samples/blob/main/01-tutorials/01-AgentCore-runtime/02-hosting-MCP-server/hosting_mcp_server.ipynb) tutorial.

# %%
# %%writefile mcp_server.py
from mcp.server.fastmcp import FastMCP

mcp = FastMCP(host="0.0.0.0", stateless_http=True)

@mcp.tool()
def getOrder() -> int:
    """Get an order"""
    return 123

@mcp.tool()
def updateOrder(orderId: int) -> int:
    """Update existing order"""
    return 456

if __name__ == "__main__":
    mcp.run(transport="streamable-http")
# Out:
# Writing mcp_server.py

# %% [markdown]
# Next, configure the AgentCore Runtime environment.

# %%
from bedrock_agentcore_starter_toolkit import Runtime
from boto3.session import Session

boto_session = Session()
region = boto_session.region_name
print(f"Using AWS region: {region}")

required_files = ['mcp_server.py', 'requirements.txt']
for file in required_files:
    if not os.path.exists(file):
        raise FileNotFoundError(f"Required file {file} not found")
print("All required files found ✓")
agentcore_runtime = Runtime()

auth_config = {
    "customJWTAuthorizer": {
        "allowedClients": [
            runtime_client_id
        ],
        "discoveryUrl": runtime_cognito_discovery_url
    }
}

print("Configuring AgentCore Runtime...")
response = agentcore_runtime.configure(
    entrypoint="mcp_server.py",
    auto_create_execution_role=True,
    auto_create_ecr=True,
    requirements_file="requirements.txt",
    region=region,
    authorizer_configuration=auth_config,
    protocol="MCP",
    agent_name="ac_gateway_mcp_server_" + user_name
)
print("Configuration completed ✓")
# Out:
# Entrypoint parsed: file=/Users/eric.fu/projects/xealth/agentcore-samples/01-tutorials/02-AgentCore-gateway/05-mcp-server-as-a-target/mcp_server.py, bedrock_agentcore_name=mcp_server
# 2026-04-09 08:07:13,214 | INFO | bedrock_agentcore_starter_toolkit.utils.runtime.entrypoint | Entrypoint parsed: file=/Users/eric.fu/projects/xealth/agentcore-samples/01-tutorials/02-AgentCore-gateway/05-mcp-server-as-a-target/mcp_server.py, bedrock_agentcore_name=mcp_server
# Memory disabled - agent will be stateless
# 2026-04-09 08:07:13,215 | INFO | bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore | Memory disabled - agent will be stateless
# Configuring BedrockAgentCore agent: ac_gateway_mcp_server_eric_fu
# 2026-04-09 08:07:13,216 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.configure | Configuring BedrockAgentCore agent: ac_gateway_mcp_server_eric_fu
# Memory disabled
# Using AWS region: us-west-2
# All required files found ✓
# Configuring AgentCore Runtime...
# 2026-04-09 08:07:13,414 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.configure | Memory disabled
# Network mode: PUBLIC
# 2026-04-09 08:07:13,415 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.configure | Network mode: PUBLIC
# 📄 Generated Dockerfile:
# /Users/eric.fu/projects/xealth/agentcore-samples/01-tutorials/02-AgentCore-gateway/05-mcp-server-as-a-target/Docker
# file
# Generated .dockerignore: /Users/eric.fu/projects/xealth/agentcore-samples/01-tutorials/02-AgentCore-gateway/05-mcp-server-as-a-target/.dockerignore
# 2026-04-09 08:07:13,422 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.configure | Generated .dockerignore: /Users/eric.fu/projects/xealth/agentcore-samples/01-tutorials/02-AgentCore-gateway/05-mcp-server-as-a-target/.dockerignore
# Setting 'ac_gateway_mcp_server_eric_fu' as default agent
# 2026-04-09 08:07:13,422 | INFO | bedrock_agentcore_starter_toolkit.utils.runtime.config | Setting 'ac_gateway_mcp_server_eric_fu' as default agent
# Bedrock AgentCore configured: /Users/eric.fu/projects/xealth/agentcore-samples/01-tutorials/02-AgentCore-gateway/05-mcp-server-as-a-target/.bedrock_agentcore.yaml
# 2026-04-09 08:07:13,424 | INFO | bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore | Bedrock AgentCore configured: /Users/eric.fu/projects/xealth/agentcore-samples/01-tutorials/02-AgentCore-gateway/05-mcp-server-as-a-target/.bedrock_agentcore.yaml
# Configuration completed ✓

# %% [markdown]
# Then, deploy to AgentCore Runtime.

# %%
print("Launching MCP server to AgentCore Runtime...")
print("This may take several minutes...")
launch_result = agentcore_runtime.launch()

agent_arn = launch_result.agent_arn
agent_id = launch_result.agent_id

encoded_arn = agent_arn.replace(':', '%3A').replace('/', '%2F')

agent_url = f'https://bedrock-agentcore.{region}.amazonaws.com/runtimes/{encoded_arn}/invocations?qualifier=DEFAULT'
print("Launch completed ✓")
print(f"Agent ARN: {agent_arn}")
print(f"Agent ID: {agent_id}")
# Out:
# 🚀 Launching Bedrock AgentCore (cloud mode - RECOMMENDED)...
# 2026-04-09 08:07:18,809 | INFO | bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore | 🚀 Launching Bedrock AgentCore (cloud mode - RECOMMENDED)...
#    • Deploy Python code directly to runtime
# 2026-04-09 08:07:18,810 | INFO | bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore |    • Deploy Python code directly to runtime
#    • No Docker required (DEFAULT behavior)
# 2026-04-09 08:07:18,810 | INFO | bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore |    • No Docker required (DEFAULT behavior)
#    • Production-ready deployment
# 2026-04-09 08:07:18,812 | INFO | bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore |    • Production-ready deployment
#
# 2026-04-09 08:07:18,815 | INFO | bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore |
# 💡 Deployment options:
# 2026-04-09 08:07:18,815 | INFO | bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore | 💡 Deployment options:
#    • runtime.launch()                → Cloud (current)
# 2026-04-09 08:07:18,816 | INFO | bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore |    • runtime.launch()                → Cloud (current)
#    • runtime.launch(local=True)      → Local development
# 2026-04-09 08:07:18,816 | INFO | bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore |    • runtime.launch(local=True)      → Local development
# Memory disabled - skipping memory creation
# 2026-04-09 08:07:18,823 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.launch | Memory disabled - skipping memory creation
# Starting CodeBuild ARM64 deployment for agent 'ac_gateway_mcp_server_eric_fu' to account 372080370602 (us-west-2)
# 2026-04-09 08:07:18,824 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.launch | Starting CodeBuild ARM64 deployment for agent 'ac_gateway_mcp_server_eric_fu' to account 372080370602 (us-west-2)
# Generated image tag: 20260409-150718-824
# 2026-04-09 08:07:18,824 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.launch | Generated image tag: 20260409-150718-824
# Setting up AWS resources (ECR repository, execution roles)...
# 2026-04-09 08:07:18,833 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.launch | Setting up AWS resources (ECR repository, execution roles)...
# Getting or creating ECR repository for agent: ac_gateway_mcp_server_eric_fu
# 2026-04-09 08:07:18,833 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.launch | Getting or creating ECR repository for agent: ac_gateway_mcp_server_eric_fu
# Launching MCP server to AgentCore Runtime...
# This may take several minutes...
# Repository doesn't exist, creating new ECR repository: bedrock-agentcore-ac_gateway_mcp_server_eric_fu
# ECR repository available: 372080370602.dkr.ecr.us-west-2.amazonaws.com/bedrock-agentcore-ac_gateway_mcp_server_eric_fu
# 2026-04-09 08:07:19,252 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.launch | ECR repository available: 372080370602.dkr.ecr.us-west-2.amazonaws.com/bedrock-agentcore-ac_gateway_mcp_server_eric_fu
# Getting or creating execution role for agent: ac_gateway_mcp_server_eric_fu
# 2026-04-09 08:07:19,260 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.launch | Getting or creating execution role for agent: ac_gateway_mcp_server_eric_fu
# Using AWS region: us-west-2, account ID: 372080370602
# 2026-04-09 08:07:19,260 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.launch | Using AWS region: us-west-2, account ID: 372080370602
# Role name: AmazonBedrockAgentCoreSDKRuntime-us-west-2-c86e97c655
# 2026-04-09 08:07:19,261 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.launch | Role name: AmazonBedrockAgentCoreSDKRuntime-us-west-2-c86e97c655
# 2026-04-09 08:07:19,263 | INFO | botocore.credentials | Found credentials in environment variables.
# Role doesn't exist, creating new execution role: AmazonBedrockAgentCoreSDKRuntime-us-west-2-c86e97c655
# 2026-04-09 08:07:19,747 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.launch | Role doesn't exist, creating new execution role: AmazonBedrockAgentCoreSDKRuntime-us-west-2-c86e97c655
# Starting execution role creation process for agent: ac_gateway_mcp_server_eric_fu
# 2026-04-09 08:07:19,748 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.launch | Starting execution role creation process for agent: ac_gateway_mcp_server_eric_fu
# ✓ Role creating: AmazonBedrockAgentCoreSDKRuntime-us-west-2-c86e97c655
# 2026-04-09 08:07:19,748 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.launch | ✓ Role creating: AmazonBedrockAgentCoreSDKRuntime-us-west-2-c86e97c655
# Creating IAM role: AmazonBedrockAgentCoreSDKRuntime-us-west-2-c86e97c655
# 2026-04-09 08:07:19,780 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.launch | Creating IAM role: AmazonBedrockAgentCoreSDKRuntime-us-west-2-c86e97c655
# ✓ Role created: arn:aws:iam::372080370602:role/AmazonBedrockAgentCoreSDKRuntime-us-west-2-c86e97c655
# 2026-04-09 08:07:19,935 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.launch | ✓ Role created: arn:aws:iam::372080370602:role/AmazonBedrockAgentCoreSDKRuntime-us-west-2-c86e97c655
# ✓ Execution policy attached: BedrockAgentCoreRuntimeExecutionPolicy-ac_gateway_mcp_server_eric_fu
# 2026-04-09 08:07:20,109 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.launch | ✓ Execution policy attached: BedrockAgentCoreRuntimeExecutionPolicy-ac_gateway_mcp_server_eric_fu
# Role creation complete and ready for use with Bedrock AgentCore
# 2026-04-09 08:07:20,110 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.launch | Role creation complete and ready for use with Bedrock AgentCore
# Execution role available: arn:aws:iam::372080370602:role/AmazonBedrockAgentCoreSDKRuntime-us-west-2-c86e97c655
# 2026-04-09 08:07:20,119 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.launch | Execution role available: arn:aws:iam::372080370602:role/AmazonBedrockAgentCoreSDKRuntime-us-west-2-c86e97c655
# Preparing CodeBuild project and uploading source...
# 2026-04-09 08:07:20,119 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.launch | Preparing CodeBuild project and uploading source...
# 2026-04-09 08:07:20,122 | INFO | botocore.credentials | Found credentials in environment variables.
# Getting or creating CodeBuild execution role for agent: ac_gateway_mcp_server_eric_fu
# 2026-04-09 08:07:20,313 | INFO | bedrock_agentcore_starter_toolkit.services.codebuild | Getting or creating CodeBuild execution role for agent: ac_gateway_mcp_server_eric_fu
# Role name: AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-c86e97c655
# 2026-04-09 08:07:20,314 | INFO | bedrock_agentcore_starter_toolkit.services.codebuild | Role name: AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-c86e97c655
# CodeBuild role doesn't exist, creating new role: AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-c86e97c655
# 2026-04-09 08:07:20,679 | INFO | bedrock_agentcore_starter_toolkit.services.codebuild | CodeBuild role doesn't exist, creating new role: AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-c86e97c655
# Creating IAM role: AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-c86e97c655
# 2026-04-09 08:07:20,684 | INFO | bedrock_agentcore_starter_toolkit.services.codebuild | Creating IAM role: AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-c86e97c655
# ✓ Role created: arn:aws:iam::372080370602:role/AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-c86e97c655
# 2026-04-09 08:07:21,086 | INFO | bedrock_agentcore_starter_toolkit.services.codebuild | ✓ Role created: arn:aws:iam::372080370602:role/AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-c86e97c655
# Attaching inline policy: CodeBuildExecutionPolicy to role: AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-c86e97c655
# 2026-04-09 08:07:21,087 | INFO | bedrock_agentcore_starter_toolkit.services.codebuild | Attaching inline policy: CodeBuildExecutionPolicy to role: AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-c86e97c655
# ✓ Policy attached: CodeBuildExecutionPolicy
# 2026-04-09 08:07:21,224 | INFO | bedrock_agentcore_starter_toolkit.services.codebuild | ✓ Policy attached: CodeBuildExecutionPolicy
# Waiting for IAM role propagation...
# 2026-04-09 08:07:21,226 | INFO | bedrock_agentcore_starter_toolkit.services.codebuild | Waiting for IAM role propagation...
# CodeBuild execution role creation complete: arn:aws:iam::372080370602:role/AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-c86e97c655
# 2026-04-09 08:07:31,231 | INFO | bedrock_agentcore_starter_toolkit.services.codebuild | CodeBuild execution role creation complete: arn:aws:iam::372080370602:role/AmazonBedrockAgentCoreSDKCodeBuild-us-west-2-c86e97c655
# Using dockerignore.template with 47 patterns for zip filtering
# 2026-04-09 08:07:31,371 | INFO | bedrock_agentcore_starter_toolkit.services.codebuild | Using dockerignore.template with 47 patterns for zip filtering
# Uploaded source to S3: ac_gateway_mcp_server_eric_fu/source.zip
# 2026-04-09 08:07:32,134 | INFO | bedrock_agentcore_starter_toolkit.services.codebuild | Uploaded source to S3: ac_gateway_mcp_server_eric_fu/source.zip
# Created CodeBuild project: bedrock-agentcore-ac_gateway_mcp_server_eric_fu-builder
# 2026-04-09 08:07:32,619 | INFO | bedrock_agentcore_starter_toolkit.services.codebuild | Created CodeBuild project: bedrock-agentcore-ac_gateway_mcp_server_eric_fu-builder
# Starting CodeBuild build (this may take several minutes)...
# 2026-04-09 08:07:32,619 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.launch | Starting CodeBuild build (this may take several minutes)...
# Starting CodeBuild monitoring...
# 2026-04-09 08:07:32,925 | INFO | bedrock_agentcore_starter_toolkit.services.codebuild | Starting CodeBuild monitoring...
# 🔄 QUEUED started (total: 0s)
# 2026-04-09 08:07:32,976 | INFO | bedrock_agentcore_starter_toolkit.services.codebuild | 🔄 QUEUED started (total: 0s)
# ✅ QUEUED completed in 1.1s
# 2026-04-09 08:07:34,037 | INFO | bedrock_agentcore_starter_toolkit.services.codebuild | ✅ QUEUED completed in 1.1s
# 🔄 PROVISIONING started (total: 1s)
# 2026-04-09 08:07:34,038 | INFO | bedrock_agentcore_starter_toolkit.services.codebuild | 🔄 PROVISIONING started (total: 1s)
# ✅ PROVISIONING completed in 8.5s
# 2026-04-09 08:07:42,537 | INFO | bedrock_agentcore_starter_toolkit.services.codebuild | ✅ PROVISIONING completed in 8.5s
# 🔄 DOWNLOAD_SOURCE started (total: 10s)
# 2026-04-09 08:07:42,538 | INFO | bedrock_agentcore_starter_toolkit.services.codebuild | 🔄 DOWNLOAD_SOURCE started (total: 10s)
# ✅ DOWNLOAD_SOURCE completed in 1.1s
# 2026-04-09 08:07:43,595 | INFO | bedrock_agentcore_starter_toolkit.services.codebuild | ✅ DOWNLOAD_SOURCE completed in 1.1s
# 🔄 BUILD started (total: 11s)
# 2026-04-09 08:07:43,595 | INFO | bedrock_agentcore_starter_toolkit.services.codebuild | 🔄 BUILD started (total: 11s)
# ✅ BUILD completed in 13.8s
# 2026-04-09 08:07:57,432 | INFO | bedrock_agentcore_starter_toolkit.services.codebuild | ✅ BUILD completed in 13.8s
# 🔄 POST_BUILD started (total: 25s)
# 2026-04-09 08:07:57,433 | INFO | bedrock_agentcore_starter_toolkit.services.codebuild | 🔄 POST_BUILD started (total: 25s)
# ✅ POST_BUILD completed in 6.4s
# 2026-04-09 08:08:03,790 | INFO | bedrock_agentcore_starter_toolkit.services.codebuild | ✅ POST_BUILD completed in 6.4s
# 🔄 FINALIZING started (total: 31s)
# 2026-04-09 08:08:03,792 | INFO | bedrock_agentcore_starter_toolkit.services.codebuild | 🔄 FINALIZING started (total: 31s)
# ✅ FINALIZING completed in 1.1s
# 2026-04-09 08:08:04,865 | INFO | bedrock_agentcore_starter_toolkit.services.codebuild | ✅ FINALIZING completed in 1.1s
# 🔄 COMPLETED started (total: 32s)
# 2026-04-09 08:08:04,866 | INFO | bedrock_agentcore_starter_toolkit.services.codebuild | 🔄 COMPLETED started (total: 32s)
# ✅ COMPLETED completed in 1.1s
# 2026-04-09 08:08:05,929 | INFO | bedrock_agentcore_starter_toolkit.services.codebuild | ✅ COMPLETED completed in 1.1s
# 🎉 CodeBuild completed successfully in 0m 33s
# 2026-04-09 08:08:05,929 | INFO | bedrock_agentcore_starter_toolkit.services.codebuild | 🎉 CodeBuild completed successfully in 0m 33s
# CodeBuild completed successfully
# 2026-04-09 08:08:05,930 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.launch | CodeBuild completed successfully
# CodeBuild project configuration saved
# 2026-04-09 08:08:05,934 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.launch | CodeBuild project configuration saved
# Deploying to Bedrock AgentCore...
# 2026-04-09 08:08:05,937 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.launch | Deploying to Bedrock AgentCore...
# 2026-04-09 08:08:05,946 | INFO | bedrock_agentcore.runtime.us-west-2 | Creating agent 'ac_gateway_mcp_server_eric_fu' with container deployment (image: 372080370602.dkr.ecr.us-west-2.amazonaws.com/bedrock-agentcore-ac_gateway_mcp_server_eric_fu:20260409-150718-824)
# 2026-04-09 08:08:06,819 | INFO | bedrock_agentcore.runtime.us-west-2 | Successfully created agent 'ac_gateway_mcp_server_eric_fu' with ID: ac_gateway_mcp_server_eric_fu-UKdYmFHeSk, ARN: arn:aws:bedrock-agentcore:us-west-2:372080370602:runtime/ac_gateway_mcp_server_eric_fu-UKdYmFHeSk
# Agent created/updated: arn:aws:bedrock-agentcore:us-west-2:372080370602:runtime/ac_gateway_mcp_server_eric_fu-UKdYmFHeSk
# 2026-04-09 08:08:06,823 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.launch | Agent created/updated: arn:aws:bedrock-agentcore:us-west-2:372080370602:runtime/ac_gateway_mcp_server_eric_fu-UKdYmFHeSk
# Observability is enabled, configuring observability components...
# 2026-04-09 08:08:06,824 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.launch | Observability is enabled, configuring observability components...
# 2026-04-09 08:08:06,840 | INFO | botocore.credentials | Found credentials in environment variables.
# CloudWatch Logs resource policy already configured
# 2026-04-09 08:08:07,065 | INFO | bedrock_agentcore_starter_toolkit.services.xray | CloudWatch Logs resource policy already configured
# X-Ray trace destination already configured
# 2026-04-09 08:08:07,226 | INFO | bedrock_agentcore_starter_toolkit.services.xray | X-Ray trace destination already configured
# X-Ray indexing rule already configured
# 2026-04-09 08:08:07,277 | INFO | bedrock_agentcore_starter_toolkit.services.xray | X-Ray indexing rule already configured
# Transaction Search already fully configured
# 2026-04-09 08:08:07,277 | INFO | bedrock_agentcore_starter_toolkit.services.xray | Transaction Search already fully configured
# 2026-04-09 08:08:07,284 | INFO | botocore.credentials | Found credentials in environment variables.
# ObservabilityDeliveryManager initialized for region: us-west-2, account: 372080370602
# 2026-04-09 08:08:07,467 | INFO | bedrock_agentcore_starter_toolkit.operations.observability.delivery | ObservabilityDeliveryManager initialized for region: us-west-2, account: 372080370602
# ✅ Logs auto-created by AWS for runtime/ac_gateway_mcp_server_eric_fu-UKdYmFHeSk
# 2026-04-09 08:08:07,469 | INFO | bedrock_agentcore_starter_toolkit.operations.observability.delivery | ✅ Logs auto-created by AWS for runtime/ac_gateway_mcp_server_eric_fu-UKdYmFHeSk
# ✅ Traces delivery enabled for runtime/ac_gateway_mcp_server_eric_fu-UKdYmFHeSk
# 2026-04-09 08:08:08,212 | INFO | bedrock_agentcore_starter_toolkit.operations.observability.delivery | ✅ Traces delivery enabled for runtime/ac_gateway_mcp_server_eric_fu-UKdYmFHeSk
# Observability enabled for runtime/ac_gateway_mcp_server_eric_fu-UKdYmFHeSk - logs: True, traces: True
# 2026-04-09 08:08:08,213 | INFO | bedrock_agentcore_starter_toolkit.operations.observability.delivery | Observability enabled for runtime/ac_gateway_mcp_server_eric_fu-UKdYmFHeSk - logs: True, traces: True
# ✅ X-Ray traces delivery enabled for agent ac_gateway_mcp_server_eric_fu-UKdYmFHeSk
# 2026-04-09 08:08:08,214 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.launch | ✅ X-Ray traces delivery enabled for agent ac_gateway_mcp_server_eric_fu-UKdYmFHeSk
# 🔍 GenAI Observability Dashboard:
# 2026-04-09 08:08:08,216 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.launch | 🔍 GenAI Observability Dashboard:
#    https://console.aws.amazon.com/cloudwatch/home?region=us-west-2#gen-ai-observability/agent-core
# 2026-04-09 08:08:08,217 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.launch |    https://console.aws.amazon.com/cloudwatch/home?region=us-west-2#gen-ai-observability/agent-core
# Polling for endpoint to be ready...
# 2026-04-09 08:08:08,218 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.launch | Polling for endpoint to be ready...
# Agent endpoint: arn:aws:bedrock-agentcore:us-west-2:372080370602:runtime/ac_gateway_mcp_server_eric_fu-UKdYmFHeSk/runtime-endpoint/DEFAULT
# 2026-04-09 08:08:08,310 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.launch | Agent endpoint: arn:aws:bedrock-agentcore:us-west-2:372080370602:runtime/ac_gateway_mcp_server_eric_fu-UKdYmFHeSk/runtime-endpoint/DEFAULT
# Deployment completed successfully - Agent: arn:aws:bedrock-agentcore:us-west-2:372080370602:runtime/ac_gateway_mcp_server_eric_fu-UKdYmFHeSk
# 2026-04-09 08:08:08,312 | INFO | bedrock_agentcore_starter_toolkit.operations.runtime.launch | Deployment completed successfully - Agent: arn:aws:bedrock-agentcore:us-west-2:372080370602:runtime/ac_gateway_mcp_server_eric_fu-UKdYmFHeSk
# Built with CodeBuild: bedrock-agentcore-ac_gateway_mcp_server_eric_fu-builder:9bebd077-ba18-4cf1-8f9f-44ca4a1a03dd
# 2026-04-09 08:08:08,313 | INFO | bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore | Built with CodeBuild: bedrock-agentcore-ac_gateway_mcp_server_eric_fu-builder:9bebd077-ba18-4cf1-8f9f-44ca4a1a03dd
# Deployed to cloud: arn:aws:bedrock-agentcore:us-west-2:372080370602:runtime/ac_gateway_mcp_server_eric_fu-UKdYmFHeSk
# 2026-04-09 08:08:08,313 | INFO | bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore | Deployed to cloud: arn:aws:bedrock-agentcore:us-west-2:372080370602:runtime/ac_gateway_mcp_server_eric_fu-UKdYmFHeSk
# ECR image: 372080370602.dkr.ecr.us-west-2.amazonaws.com/bedrock-agentcore-ac_gateway_mcp_server_eric_fu:20260409-150718-824
# 2026-04-09 08:08:08,314 | INFO | bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore | ECR image: 372080370602.dkr.ecr.us-west-2.amazonaws.com/bedrock-agentcore-ac_gateway_mcp_server_eric_fu:20260409-150718-824
# 🔍 Agent logs available at:
# 2026-04-09 08:08:08,315 | INFO | bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore | 🔍 Agent logs available at:
#    /aws/bedrock-agentcore/runtimes/ac_gateway_mcp_server_eric_fu-UKdYmFHeSk-DEFAULT --log-stream-name-prefix "2026/04/09/\[runtime-logs]"
# 2026-04-09 08:08:08,315 | INFO | bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore |    /aws/bedrock-agentcore/runtimes/ac_gateway_mcp_server_eric_fu-UKdYmFHeSk-DEFAULT --log-stream-name-prefix "2026/04/09/\[runtime-logs]"
#    /aws/bedrock-agentcore/runtimes/ac_gateway_mcp_server_eric_fu-UKdYmFHeSk-DEFAULT --log-stream-names "otel-rt-logs"
# 2026-04-09 08:08:08,316 | INFO | bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore |    /aws/bedrock-agentcore/runtimes/ac_gateway_mcp_server_eric_fu-UKdYmFHeSk-DEFAULT --log-stream-names "otel-rt-logs"
# 💡 Tail logs with: aws logs tail /aws/bedrock-agentcore/runtimes/ac_gateway_mcp_server_eric_fu-UKdYmFHeSk-DEFAULT --log-stream-name-prefix "2026/04/09/\[runtime-logs]" --follow
# 2026-04-09 08:08:08,316 | INFO | bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore | 💡 Tail logs with: aws logs tail /aws/bedrock-agentcore/runtimes/ac_gateway_mcp_server_eric_fu-UKdYmFHeSk-DEFAULT --log-stream-name-prefix "2026/04/09/\[runtime-logs]" --follow
# 💡 Or view recent logs: aws logs tail /aws/bedrock-agentcore/runtimes/ac_gateway_mcp_server_eric_fu-UKdYmFHeSk-DEFAULT --log-stream-name-prefix "2026/04/09/\[runtime-logs]" --since 1h
# 2026-04-09 08:08:08,317 | INFO | bedrock_agentcore_starter_toolkit.notebook.runtime.bedrock_agentcore | 💡 Or view recent logs: aws logs tail /aws/bedrock-agentcore/runtimes/ac_gateway_mcp_server_eric_fu-UKdYmFHeSk-DEFAULT --log-stream-name-prefix "2026/04/09/\[runtime-logs]" --since 1h
# Launch completed ✓
# Agent ARN: arn:aws:bedrock-agentcore:us-west-2:372080370602:runtime/ac_gateway_mcp_server_eric_fu-UKdYmFHeSk
# Agent ID: ac_gateway_mcp_server_eric_fu-UKdYmFHeSk

# %% [markdown]
# ## Create an MCP server as target for AgentCore Gateway

# %% [markdown]
# ### Configure Outbound Auth
#
# First, we will create an AgentCore Identity Resource Credential Provider for our AgentCore Gateway to use as outbound auth to our MCP server in AgentCore Runtime.

# %%
import boto3
identity_client = boto3.client('bedrock-agentcore-control', region_name=REGION)

cognito_provider = identity_client.create_oauth2_credential_provider(
    name="ac-gateway-mcp-server-identity-" + user_name.replace("_", "-"),
    credentialProviderVendor="CustomOauth2",
    oauth2ProviderConfigInput={
        'customOauth2ProviderConfig': {
            'oauthDiscovery': {
                'discoveryUrl': runtime_cognito_discovery_url,
            },
            'clientId': runtime_client_id,
            'clientSecret': runtime_client_secret
        }
    }
)
cognito_provider_arn = cognito_provider['credentialProviderArn']
print(cognito_provider_arn)
# Out:
# arn:aws:bedrock-agentcore:us-west-2:372080370602:token-vault/default/oauth2credentialprovider/ac-gateway-mcp-server-identity-eric-fu

# %% [markdown]
# ### Create the Gateway Target

# %%
import boto3
gateway_client = boto3.client('bedrock-agentcore-control', region_name=REGION)
create_gateway_target_response = gateway_client.create_gateway_target(
    name='mcp-server-target',
    gatewayIdentifier=gatewayID,
    targetConfiguration={
        'mcp': {
            'mcpServer': {
                'endpoint': agent_url
            }
        }
    },
    credentialProviderConfigurations=[
        {
            'credentialProviderType': 'OAUTH',
            'credentialProvider': {
                'oauthCredentialProvider': {
                    'providerArn': cognito_provider_arn,
                    'scopes': [
                        runtimeScopeString
                    ]
                }
            }
        },
    ]
)
print(create_gateway_target_response)
# Out:
# {'ResponseMetadata': {'RequestId': '401f7268-b5b9-4de6-9573-ba7a5c2006d9', 'HTTPStatusCode': 202, 'HTTPHeaders': {'date': 'Thu, 09 Apr 2026 15:17:04 GMT', 'content-type': 'application/json', 'content-length': '886', 'connection': 'keep-alive', 'x-amzn-requestid': '401f7268-b5b9-4de6-9573-ba7a5c2006d9', 'x-amz-apigw-id': 'bjtliFGNPHcEZMg=', 'x-amzn-trace-id': 'Root=1-69d7c2ef-50386b613db13e237bce1f47'}, 'RetryAttempts': 0}, 'gatewayArn': 'arn:aws:bedrock-agentcore:us-west-2:372080370602:gateway/ac-gateway-mcp-server-eric-fu-vm1cliffaw', 'targetId': 'Y8O2SAMZES', 'createdAt': datetime.datetime(2026, 4, 9, 15, 17, 4, 3467, tzinfo=tzutc()), 'updatedAt': datetime.datetime(2026, 4, 9, 15, 17, 4, 3477, tzinfo=tzutc()), 'status': 'CREATING', 'name': 'mcp-server-target', 'targetConfiguration': {'mcp': {'mcpServer': {'endpoint': 'https://bedrock-agentcore.us-west-2.amazonaws.com/runtimes/arn%3Aaws%3Abedrock-agentcore%3Aus-west-2%3A372080370602%3Aruntime%2Fac_gateway_mcp_server_eric_fu-UKdYmFHeSk/invocations?qualifier=DEFAULT'}}}, 'credentialProviderConfigurations': [{'credentialProviderType': 'OAUTH', 'credentialProvider': {'oauthCredentialProvider': {'providerArn': 'arn:aws:bedrock-agentcore:us-west-2:372080370602:token-vault/default/oauth2credentialprovider/ac-gateway-mcp-server-identity-eric-fu', 'scopes': ['sample-agentcore-runtime-id/invoke'], 'grantType': 'CLIENT_CREDENTIALS'}}}]}

# %% [markdown]
# #### Check that the Gateway target exists, and is READY

# %%
list_targets_response = gateway_client.list_gateway_targets(gatewayIdentifier=gatewayID)
print(list_targets_response)
# Out:
# {'ResponseMetadata': {'RequestId': 'd26316f7-0345-4785-931c-fd8a7bb3b242', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Thu, 09 Apr 2026 15:17:08 GMT', 'content-type': 'application/json', 'content-length': '174', 'connection': 'keep-alive', 'x-amzn-requestid': 'd26316f7-0345-4785-931c-fd8a7bb3b242', 'x-amz-apigw-id': 'bjtmNGHBvHcEEZQ=', 'x-amzn-trace-id': 'Root=1-69d7c2f4-12c4fab30076910b14cc5aa9'}, 'RetryAttempts': 0}, 'items': [{'targetId': 'Y8O2SAMZES', 'name': 'mcp-server-target', 'status': 'CREATING', 'createdAt': datetime.datetime(2026, 4, 9, 15, 17, 4, 3467, tzinfo=tzutc()), 'updatedAt': datetime.datetime(2026, 4, 9, 15, 17, 4, 3477, tzinfo=tzutc())}]}

# %% [markdown]
# #### Request the access token from Amazon Cognito for inbound authorization

# %%
print("Requesting the access token from Amazon Cognito authorizer...May fail for some time till the domain name propagation completes")
token_response = utils.get_token(gw_user_pool_id, gw_client_id, gw_client_secret, scopeString, REGION)
token = token_response["access_token"]
print("Token response:", token)
# Out:
# Requesting the access token from Amazon Cognito authorizer...May fail for some time till the domain name propagation completes
# 13p3t4o8fr1egchooj4pl9v5vr
# Token response: eyJraWQiOiJoSnNSRllzd1dvcFlNQXE3WUJDXC9jNjNVODlSNVZPeG1YS0VcL2szUytzZDA9IiwiYWxnIjoiUlMyNTYifQ.....aOVjiF6gwdZKBFmlG1EA8FJ75XnPk6TCpPB5cUz09xOBaW2UGmbeTHyVnNK7P_GHvgbZ333Puc6eSbztf5EWfsS5FmKmugkWg-7dEORFWLfJ0KMlvyKon4biHljuTZZxTaj05wrDA1e-8CQhSkFlDivbaMA3Itu6Z1U-O_kNQ9d8axgkEWzNL19Gaej3BQeKmAcR00RU9W_EUOz1nyE-JX_bhNMg2V8voXXzqD8X_uu5P4CpK61TpWxevneam2MBmXAzTqZXV1GwFkCTNqum_sFOAgabwqRvEO5s2e7-LkexPMm9r2xSDrZWF4fIL6XUupbfPiTqohrt6vVpXZFgTg

# %% [markdown]
# ## Search for MCP Server tools through the Gateway

# %%
import requests
import json

def search_tools(gateway_url, access_token, query):
    headers = {
        "Content-Type": "application/json",
        "Authorization": f"Bearer {access_token}"
    }

    payload = {
        "jsonrpc": "2.0",
        "id": "search-tools-request",
        "method": "tools/call",
        "params": {
            "name": "x_amz_bedrock_agentcore_search",
            "arguments": {
                "query": query
            }
        }
    }

    response = requests.post(gateway_url, headers=headers, json=payload)
    return response.json()

# Example usage
token_response = utils.get_token(gw_user_pool_id, gw_client_id, gw_client_secret, scopeString, REGION)
access_token = token_response['access_token']
results = search_tools(gatewayURL, access_token, "orders")
print(json.dumps(results, indent=2))
# Out:
# 13p3t4o8fr1egchooj4pl9v5vr
# {
#   "jsonrpc": "2.0",
#   "id": "search-tools-request",
#   "result": {
#     "structuredContent": {
#       "tools": [
#         {
#           "name": "mcp-server-target___getOrder",
#           "description": "Get an order",
#           "inputSchema": {
#             "type": "object",
#             "properties": {}
#           },
#           "outputSchema": {
#             "properties": {
#               "result": {
#                 "title": "Result",
#                 "type": "integer"
#               }
#             },
#             "required": [
#               "result"
#             ],
#             "title": "getOrderOutput",
#             "type": "object"
#           }
#         },
#         {
#           "name": "mcp-server-target___updateOrder",
#           "description": "Update existing order",
#           "inputSchema": {
#             "type": "object",
#             "properties": {
#               "orderId": {
#                 "title": "Orderid",
#                 "type": "integer"
#               }
#             },
#             "required": [
#               "orderId"
#             ]
#           },
#           "outputSchema": {
#             "properties": {
#               "result": {
#                 "title": "Result",
#                 "type": "integer"
#               }
#             },
#             "required": [
#               "result"
#             ],
#             "title": "updateOrderOutput",
#             "type": "object"
#           }
#         }
#       ]
#     },
#     "isError": false,
#     "content": [
#       {
#         "type": "text",
#         "text": "{\"tools\":[{\"name\":\"mcp-server-target___getOrder\",\"description\":\"Get an order\",\"inputSchema\":{\"type\":\"object\",\"properties\":{}},\"outputSchema\":{\"properties\":{\"result\":{\"title\":\"Result\",\"type\":\"integer\"}},\"required\":[\"result\"],\"title\":\"getOrderOutput\",\"type\":\"object\"}},{\"name\":\"mcp-server-target___updateOrder\",\"description\":\"Update existing order\",\"inputSchema\":{\"type\":\"object\",\"properties\":{\"orderId\":{\"title\":\"Orderid\",\"type\":\"integer\"}},\"required\":[\"orderId\"]},\"outputSchema\":{\"properties\":{\"result\":{\"title\":\"Result\",\"type\":\"integer\"}},\"required\":[\"result\"],\"title\":\"updateOrderOutput\",\"type\":\"object\"}}]}"
#       }
#     ]
#   }
# }

# %% [markdown]
# For more relevant examples on AgentCore Gateway search functionality, see [03-search-tools](../03-search-tools).

# %% [markdown]
# ## Use an agent to operate on orders via the Gateway

# %%
import json

import requests
from strands.models import BedrockModel
from mcp.client.streamable_http import streamablehttp_client
from strands.tools.mcp.mcp_client import MCPClient
from strands import Agent


def get_token():
    token = utils.get_token(gw_user_pool_id, gw_client_id, gw_client_secret, scopeString, REGION)
    return token['access_token']


def create_streamable_http_transport():
    return streamablehttp_client(
        gatewayURL, headers={"Authorization": f"Bearer {get_token()}"}
    )


client = MCPClient(create_streamable_http_transport)

## The IAM group/user/ configured in ~/.aws/credentials should have access to Bedrock model
yourmodel = BedrockModel(
    model_id="global.anthropic.claude-haiku-4-5-20251001-v1:0", # may need to update model_id depending on region
    temperature=0.7,
    max_tokens=500,  # Limit response length
)

with client:
    # Call the listTools
    tools = client.list_tools_sync()
    # Create an Agent with the model and tools
    agent = Agent(
        model=yourmodel, tools=tools
    )  ## you can replace with any model you like
    # Invoke the agent with the sample prompt. This will only invoke MCP listTools and retrieve the list of tools the LLM has access to. The below does not actually call any tool.
    agent("Hi, can you list all tools available to you")
    # Simplified prompt and error handling
    result = agent("Update order 123")
# Out:
# 2026-04-09 08:17:38,469 | INFO | botocore.credentials | Found credentials in environment variables.
# 13p3t4o8fr1egchooj4pl9v5vr
# 2026-04-09 08:17:38,944 | INFO | httpx | HTTP Request: POST https://ac-gateway-mcp-server-eric-fu-vm1cliffaw.gateway.bedrock-agentcore.us-west-2.amazonaws.com/mcp "HTTP/1.1 200 OK"
# 2026-04-09 08:17:38,945 | INFO | mcp.client.streamable_http | Negotiated protocol version: 2025-03-26
# 2026-04-09 08:17:39,059 | INFO | httpx | HTTP Request: POST https://ac-gateway-mcp-server-eric-fu-vm1cliffaw.gateway.bedrock-agentcore.us-west-2.amazonaws.com/mcp "HTTP/1.1 202 Accepted"
# 2026-04-09 08:17:39,254 | INFO | httpx | HTTP Request: POST https://ac-gateway-mcp-server-eric-fu-vm1cliffaw.gateway.bedrock-agentcore.us-west-2.amazonaws.com/mcp "HTTP/1.1 200 OK"
# 2026-04-09 08:17:39,262 | INFO | strands.telemetry.metrics | Creating Strands MetricsClient
# I'll search for all available tools for you.
# Tool #1: x_amz_bedrock_agentcore_search
# 2026-04-09 08:17:42,455 | INFO | httpx | HTTP Request: POST https://ac-gateway-mcp-server-eric-fu-vm1cliffaw.gateway.bedrock-agentcore.us-west-2.amazonaws.com/mcp "HTTP/1.1 200 OK"
# Based on the available tools, here are all the tools I have access to:
#
# 1. **getOrder** (`mcp-server-target___getOrder`)
#    - **Description**: Get an order
#    - **Parameters**: None required
#    - **Output**: Returns an integer result
#
# 2. **updateOrder** (`mcp-server-target___updateOrder`)
#    - **Description**: Update existing order
#    - **Parameters**:
#      - `orderId` (required, integer): The ID of the order to update
#    - **Output**: Returns an integer result
#
# These are the two order management tools currently available to me. Would you like me to help you with getting or updating an order?
# Tool #2: mcp-server-target___updateOrder
# 2026-04-09 08:17:53,748 | INFO | httpx | HTTP Request: POST https://ac-gateway-mcp-server-eric-fu-vm1cliffaw.gateway.bedrock-agentcore.us-west-2.amazonaws.com/mcp "HTTP/1.1 200 OK"
# Done! I've successfully updated order 123. The operation returned a result value of 456.

# %% [markdown]
# ## Clean up
# Additional resources are also created like IAM role, IAM Policies, Credentials provider, AWS Lambda functions, Cognito user pools, s3 buckets that you might need to manually delete as part of the clean up. This depends on the example you run.
#
# ### NOTE: if you are moving on to the next notebook, [02-mcp-target-synchronization](02-mcp-target-synchronization.ipynb), we suggest retaining these resources for the next tutorial.

# %% [markdown]
# ### Delete the Gateway (Optional)

# %%
utils.delete_gateway(gateway_client, gatewayID)
# Out:
# Deleting all targets for gateway ac-gateway-mcp-server-eric-fu-vm1cliffaw
# Deleting target  Y8O2SAMZES
# Deleting gateway  ac-gateway-mcp-server-eric-fu-vm1cliffaw

# %% [markdown]
# ### Delete the Identity Provider (Optional)

# %%
identity_client.delete_oauth2_credential_provider(name='ac-gateway-mcp-server-identity-' + user_name.replace("_", "-"))
# Out:
# {'ResponseMetadata': {'RequestId': '52a0a489-d0ac-4e3b-be5c-ff1181215746',
#   'HTTPStatusCode': 204,
#   'HTTPHeaders': {'date': 'Thu, 09 Apr 2026 15:18:18 GMT',
#    'content-type': 'application/json',
#    'content-length': '0',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': '52a0a489-d0ac-4e3b-be5c-ff1181215746',
#    'x-amzn-remapped-x-amzn-requestid': '311084ce-33da-4762-8156-dac1d082b79f',
#    'x-amzn-remapped-connection': 'keep-alive',
#    'x-amz-apigw-id': 'bjtxOGTKPHcEeVw=',
#    'x-amzn-trace-id': 'Root=1-69d7c33a-7886de060900b7db48738c92',
#    'x-amzn-remapped-date': 'Thu, 09 Apr 2026 15:18:18 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ### Delete the Runtime (Optional)

# %%
import boto3
runtime_client = boto3.client('bedrock-agentcore-control', region_name=REGION)
runtime_client.delete_agent_runtime(agentRuntimeId=agent_id)
# Out:
# {'ResponseMetadata': {'RequestId': '5260bda3-291b-4499-9e8e-139772496243',
#   'HTTPStatusCode': 202,
#   'HTTPHeaders': {'date': 'Thu, 09 Apr 2026 15:18:25 GMT',
#    'content-type': 'application/json',
#    'content-length': '81',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': '5260bda3-291b-4499-9e8e-139772496243',
#    'x-amz-apigw-id': 'bjtySHIlvHcENZQ=',
#    'x-amzn-trace-id': 'Root=1-69d7c341-7304159d45b744be2cd232ae'},
#   'RetryAttempts': 0},
#  'status': 'DELETING',
#  'agentRuntimeId': 'ac_gateway_mcp_server_eric_fu-UKdYmFHeSk'}

# %% [markdown]
# # Manually delete the two Cognito User Pools
#
# * sample-agentcore-gateway-pool-<your-name>
# * sample-agentcore-runtime-pool-<your-name>
